# %% [markdown]
# ResNet18

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader
import copy
import random
import numpy as np
import pandas as pd

data_dir = r"C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\COMP9517_Team_500_40_10\content/Team_Dataset"

batch_size = 32
num_classes = 500
num_epochs = 60
LR = 1e-3
RUN_ID = 'r18_Scratch_Full_Aug'

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Training on device: {device}")
SEED = 42
random.seed(SEED); np.random.seed(SEED)
torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = True
# Out:
# Training on device: cuda:0

# %% [markdown]
# Data Augmentation: Full

# %%
data_transforms_fully_aug = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224, scale=(0.5, 1.0)),    # takes a random patch of the photo and stretches it to 224×224. Half the image is a safer floor for fine-grained work.
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(brightness=0.3, contrast=0.3,
                               saturation=0.3, hue=0.03),       # Requires Fine Tuning
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        transforms.RandomErasing(p=0.25, scale=(0.02, 0.2)),    # blanks out a random rectangle after the image is a tensor
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms_fully_aug[x]) for x in ['train', 'val']}  # For Full Aug
dataloaders = {x: DataLoader(image_datasets[x], batch_size=batch_size, shuffle=(x == 'train'), num_workers=8, persistent_workers=True, pin_memory=True) for x in ['train', 'val']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}

model = models.resnet18(weights=None)

num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, num_classes) 
model = model.to(device)

criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = optim.AdamW(model.parameters(), lr=LR, weight_decay=1e-4)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)
class_names = image_datasets['train'].classes

# %% [markdown]
# Training

# %%
train_losses, val_losses = [], []
train_accs, val_accs = [], []

best_model_wts = copy.deepcopy(model.state_dict())                              # stored weights of the best model
best_acc = 0.0

print("Starting Experiment 2: ResNet18 From Scratch (Full Augmentation)")
for epoch in range(num_epochs):
    print(f'Epoch {epoch+1}/{num_epochs}')
    print('-' * 10)

    for phase in ['train', 'val']:
        if phase == 'train':
            model.train()       # Uses current batch statistics
        else:           
            model.eval()        # Uses running averages

        running_loss = 0.0
        running_corrects = 0

        for inputs, labels in dataloaders[phase]:
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()       # Clears gradients

            with torch.set_grad_enabled(phase == 'train'):
                outputs = model(inputs)         # 32 Images as Input, 32 x 500 grid, where each image golds the score for all 500 species
                _, preds = torch.max(outputs, 1)    # Minds the maximum score from the 500 row, returns score value and position - position correlates directly to the actual species
                loss = criterion(outputs, labels)

                # Actual physical training
                if phase == 'train':
                    loss.backward()     # Calculates what direction the model should moves to reduce the loss
                    optimizer.step()    # Actualy moves the weights by amount (learning rate)

            running_loss += loss.item() * inputs.size(0)        #average loss for that batch
            running_corrects += torch.sum(preds == labels.data) #Sum of all predictions that were correct

        epoch_loss = running_loss / dataset_sizes[phase]
        epoch_acc = (running_corrects.double() / dataset_sizes[phase]).item()

        print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

        if phase == 'train':
            train_losses.append(epoch_loss)
            train_accs.append(epoch_acc)
        else:
            val_losses.append(epoch_loss)
            val_accs.append(epoch_acc)

            if epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                torch.save(model.state_dict(), rf'C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\ResNet18\From Scratch\{RUN_ID}_best.pth')

    print()

    pd.DataFrame({
        'epoch': range(1, len(train_losses) + 1),
        'train_loss': train_losses, 'train_acc': train_accs,
        'val_loss': val_losses, 'val_acc': val_accs,
    }).to_csv(rf'C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\ResNet18\From Scratch\{RUN_ID}_history.csv', index=False)

    scheduler.step()

model.load_state_dict(best_model_wts)

print(f'Experiment 2 Complete. Best Validation Accuracy: {best_acc:.4f}')
# Out:
# Starting Experiment 2: ResNet18 From Scratch (Full Augmentation)
# Epoch 1/60
# ----------
# Train Loss: 6.1758 Acc: 0.0044
# Val Loss: 6.3906 Acc: 0.0046
#
# Epoch 2/60
# ----------
# Train Loss: 5.9130 Acc: 0.0092
# Val Loss: 5.7774 Acc: 0.0160
#
# Epoch 3/60
# ----------
# Train Loss: 5.7344 Acc: 0.0174
# Val Loss: 5.5957 Acc: 0.0266
#
# Epoch 4/60
# ----------
# Train Loss: 5.5833 Acc: 0.0253
# Val Loss: 5.6107 Acc: 0.0316
#
# Epoch 5/60
# ----------
# Train Loss: 5.4069 Acc: 0.0384
# Val Loss: 5.2385 Acc: 0.0610
#
# Epoch 6/60
# ----------
# Train Loss: 5.2310 Acc: 0.0567
# Val Loss: 5.1085 Acc: 0.0818
#
# Epoch 7/60
# ----------
# Train Loss: 5.0662 Acc: 0.0771
# Val Loss: 5.0578 Acc: 0.0914
#
# Epoch 8/60
# ----------
# Train Loss: 4.9003 Acc: 0.0954
# Val Loss: 4.8945 Acc: 0.1130
#
# Epoch 9/60
# ----------
# Train Loss: 4.7374 Acc: 0.1160
# Val Loss: 4.7598 Acc: 0.1328
#
# Epoch 10/60
# ----------
# Train Loss: 4.5922 Acc: 0.1411
# Val Loss: 4.5948 Acc: 0.1468
#
# Epoch 11/60
# ----------
# Train Loss: 4.4467 Acc: 0.1676
# Val Loss: 4.4752 Acc: 0.1730
#
# Epoch 12/60
# ----------
# Train Loss: 4.3067 Acc: 0.1925
# Val Loss: 4.4137 Acc: 0.1840
#
# Epoch 13/60
# ----------
# Train Loss: 4.1628 Acc: 0.2191
# Val Loss: 4.3347 Acc: 0.2074
#
# Epoch 14/60
# ----------
# Train Loss: 4.0400 Acc: 0.2380
# Val Loss: 4.2296 Acc: 0.2276
#
# Epoch 15/60
# ----------
# Train Loss: 3.9128 Acc: 0.2656
# Val Loss: 4.2108 Acc: 0.2332
#
# Epoch 16/60
# ----------
# Train Loss: 3.7992 Acc: 0.2876
# Val Loss: 4.1210 Acc: 0.2534
#
# Epoch 17/60
# ----------
# Train Loss: 3.6766 Acc: 0.3143
# Val Loss: 4.0827 Acc: 0.2604
#
# Epoch 18/60
# ----------
# Train Loss: 3.5659 Acc: 0.3417
# Val Loss: 4.0814 Acc: 0.2732
#
# Epoch 19/60
# ----------
# Train Loss: 3.4460 Acc: 0.3653
# Val Loss: 4.0219 Acc: 0.2906
#
# Epoch 20/60
# ----------
# Train Loss: 3.3385 Acc: 0.3917
# Val Loss: 4.0038 Acc: 0.2952
#
# Epoch 21/60
# ----------
# Train Loss: 3.2325 Acc: 0.4182
# Val Loss: 4.0096 Acc: 0.2974
#
# Epoch 22/60
# ----------
# Train Loss: 3.1401 Acc: 0.4391
# Val Loss: 4.2443 Acc: 0.2986
#
# Epoch 23/60
# ----------
# Train Loss: 3.0336 Acc: 0.4704
# Val Loss: 3.9086 Acc: 0.3156
#
# Epoch 24/60
# ----------
# Train Loss: 2.9388 Acc: 0.4899
# Val Loss: 3.9055 Acc: 0.3278
#
# Epoch 25/60
# ----------
# Train Loss: 2.8410 Acc: 0.5193
# Val Loss: 3.9007 Acc: 0.3410
#
# Epoch 26/60
# ----------
# Train Loss: 2.7473 Acc: 0.5440
# Val Loss: 3.9723 Acc: 0.3246
#
# Epoch 27/60
# ----------
# Train Loss: 2.6622 Acc: 0.5706
# Val Loss: 3.8399 Acc: 0.3494
#
# Epoch 28/60
# ----------
# Train Loss: 2.5746 Acc: 0.5941
# Val Loss: 3.9020 Acc: 0.3520
#
# Epoch 29/60
# ----------
# Train Loss: 2.4904 Acc: 0.6191
# Val Loss: 3.8304 Acc: 0.3540
#
# Epoch 30/60
# ----------
# Train Loss: 2.4139 Acc: 0.6435
# Val Loss: 3.8247 Acc: 0.3606
#
# Epoch 31/60
# ----------
# Train Loss: 2.3405 Acc: 0.6656
# Val Loss: 3.7931 Acc: 0.3672
#
# Epoch 32/60
# ----------
# Train Loss: 2.2653 Acc: 0.6911
# Val Loss: 3.8160 Acc: 0.3608
#
# Epoch 33/60
# ----------
# Train Loss: 2.1972 Acc: 0.7143
# Val Loss: 3.9323 Acc: 0.3582
#
# Epoch 34/60
# ----------
# Train Loss: 2.1444 Acc: 0.7316
# Val Loss: 3.7973 Acc: 0.3694
#
# Epoch 35/60
# ----------
# Train Loss: 2.0808 Acc: 0.7516
# Val Loss: 3.8788 Acc: 0.3652
#
# Epoch 36/60
# ----------
# Train Loss: 2.0249 Acc: 0.7697
# Val Loss: 3.8400 Acc: 0.3642
#
# Epoch 37/60
# ----------
# Train Loss: 1.9758 Acc: 0.7914
# Val Loss: 3.8077 Acc: 0.3756
#
# Epoch 38/60
# ----------
# Train Loss: 1.9193 Acc: 0.8086
# Val Loss: 3.8951 Acc: 0.3764
#
# Epoch 39/60
# ----------
# Train Loss: 1.8819 Acc: 0.8241
# Val Loss: 3.8269 Acc: 0.3790
#
# Epoch 40/60
# ----------
# Train Loss: 1.8384 Acc: 0.8384
# Val Loss: 3.8300 Acc: 0.3826
#
# Epoch 41/60
# ----------
# Train Loss: 1.7977 Acc: 0.8506
# Val Loss: 3.8795 Acc: 0.3800
#
# Epoch 42/60
# ----------
# Train Loss: 1.7607 Acc: 0.8663
# Val Loss: 3.8353 Acc: 0.3804
#
# Epoch 43/60
# ----------
# Train Loss: 1.7457 Acc: 0.8664
# Val Loss: 3.7778 Acc: 0.3892
#
# Epoch 44/60
# ----------
# Train Loss: 1.7089 Acc: 0.8776
# Val Loss: 3.7623 Acc: 0.3844
#
# Epoch 45/60
# ----------
# Train Loss: 1.6772 Acc: 0.8905
# Val Loss: 3.7639 Acc: 0.3878
#
# Epoch 46/60
# ----------
# Train Loss: 1.6528 Acc: 0.9007
# Val Loss: 3.8364 Acc: 0.3850
#
# Epoch 47/60
# ----------
# Train Loss: 1.6345 Acc: 0.9022
# Val Loss: 3.7895 Acc: 0.3908
#
# Epoch 48/60
# ----------
# Train Loss: 1.6114 Acc: 0.9143
# Val Loss: 3.7313 Acc: 0.3958
#
# Epoch 49/60
# ----------
# Train Loss: 1.6071 Acc: 0.9124
# Val Loss: 3.7339 Acc: 0.3958
#
# Epoch 50/60
# ----------
# Train Loss: 1.5854 Acc: 0.9187
# Val Loss: 3.7335 Acc: 0.3904
#
# Epoch 51/60
# ----------
# Train Loss: 1.5697 Acc: 0.9247
# Val Loss: 3.8071 Acc: 0.3886
#
# Epoch 52/60
# ----------
# Train Loss: 1.5588 Acc: 0.9290
# Val Loss: 3.7280 Acc: 0.3980
#
# Epoch 53/60
# ----------
# Train Loss: 1.5551 Acc: 0.9302
# Val Loss: 3.7177 Acc: 0.3912
#
# Epoch 54/60
# ----------
# Train Loss: 1.5439 Acc: 0.9309
# Val Loss: 3.7595 Acc: 0.3916
#
# Epoch 55/60
# ----------
# Train Loss: 1.5350 Acc: 0.9341
# Val Loss: 3.7260 Acc: 0.3942
#
# Epoch 56/60
# ----------
# Train Loss: 1.5374 Acc: 0.9359
# Val Loss: 3.6999 Acc: 0.3940
#
# Epoch 57/60
# ----------
# Train Loss: 1.5384 Acc: 0.9335
# Val Loss: 3.7583 Acc: 0.3936
#
# Epoch 58/60
# ----------
# Train Loss: 1.5281 Acc: 0.9365
# Val Loss: 3.6944 Acc: 0.3962
#
# Epoch 59/60
# ----------
# Train Loss: 1.5261 Acc: 0.9355
# Val Loss: 3.8403 Acc: 0.3864
#
# Epoch 60/60
# ----------
# Train Loss: 1.5212 Acc: 0.9370
# Val Loss: 3.7296 Acc: 0.3946
#
# Experiment 2 Complete. Best Validation Accuracy: 0.3980

# %% [markdown]
# Loss/ Accuracy Curves

# %%
import matplotlib.pyplot as plt
CKPT = r"C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\ResNet18\From Scratch"
EVAL_SPLIT = 'test' 

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs+1), train_losses, label='Train Loss', color='blue')
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss', color='red')
plt.title('Experiment 2: Loss Curve (Full Aug. From Scratch)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs+1), train_accs, label='Train Accuracy', color='blue')
plt.plot(range(1, num_epochs+1), val_accs, label='Validation Accuracy', color='red')
plt.title('Experiment 2: Accuracy Curve (Full Aug. From Scratch)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig(os.path.join(CKPT, f'{RUN_ID}_Loss_Accuracy_Curve.png'), dpi=150)
plt.show()

# %% [markdown]
# Performance Metric Prep.

# %%
import time

CKPT = r"C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\ResNet18\From Scratch"

EVAL_SPLIT = 'test'       

# model.load_state_dict(torch.load(os.path.join(CKPT, 'exp1_scratch_best.pth')))
# model = model.to(device)

eval_ds = datasets.ImageFolder(os.path.join(data_dir, EVAL_SPLIT), data_transforms_fully_aug['val'])
assert eval_ds.classes == image_datasets['train'].classes, "class lists differ!"
eval_dl = DataLoader(eval_ds, batch_size=batch_size, shuffle=False, num_workers=2)
class_names = eval_ds.classes

model.eval()
all_top5, all_conf = [], []

if device.type == 'cuda': torch.cuda.synchronize()
t0 = time.time()

with torch.no_grad():
    for inputs, _ in eval_dl:
        probs = model(inputs.to(device)).softmax(1)
        conf, top5 = probs.topk(5, dim=1)
        all_top5.append(top5.cpu())
        all_conf.append(conf[:, 0].cpu())

if device.type == 'cuda': torch.cuda.synchronize()
infer_secs = time.time() - t0

top5 = torch.cat(all_top5).numpy()

df = pd.DataFrame({
    'filepath':   [p for p, _ in eval_ds.samples],
    'true':       [y for _, y in eval_ds.samples],
    'pred':       top5[:, 0],
    'confidence': torch.cat(all_conf).numpy(),
})
for k in range(5):
    df[f'top{k+1}'] = top5[:, k]

df.to_csv(os.path.join(CKPT, f'{RUN_ID}_predictions.csv'), index=False)
print(f'{len(df)} images in {infer_secs:.1f}s  ({infer_secs*1000/len(df):.2f} ms/image)')
# Out:
# 5000 images in 11.3s  (2.26 ms/image)

# %% [markdown]
# Numerical Performance Metric

# %%
from sklearn.metrics import precision_recall_fscore_support, balanced_accuracy_score

df = pd.read_csv(os.path.join(CKPT, f'{RUN_ID}_predictions.csv'))

top1 = (df['pred'] == df['true']).mean()

top5_cols = [f'top{k}' for k in range(1, 6)]
top5_acc = (df[top5_cols].values == df['true'].values[:, None]).any(axis=1).mean()

p, r, f1, _ = precision_recall_fscore_support(
    df['true'], df['pred'], average='macro', zero_division=0)
bal = balanced_accuracy_score(df['true'], df['pred'])

print(f"Top-1 accuracy  : {top1:.4f}")
print(f"Top-5 accuracy  : {top5_acc:.4f}")
print(f"Balanced acc    : {bal:.4f}")
print(f"Macro precision : {p:.4f}")
print(f"Macro recall    : {r:.4f}")
print(f"Macro F1        : {f1:.4f}")

summary_path = os.path.join(r"C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\ResNet50\From Scratch\summary.csv")
pd.DataFrame([{
    'run': RUN_ID, 'arch': 'resnet18', 'augmentation': 'full',
    'epochs': num_epochs, 'top1': top1, 'top5': top5_acc, 'balanced_acc': bal,
    'macro_p': p, 'macro_r': r, 'macro_f1': f1,
    'best_val_acc': best_acc, 'ms_per_img': infer_secs * 1000 / len(df),
}]).to_csv(summary_path, mode='a', header=not os.path.exists(summary_path), index=False)
# Out:
# Top-1 accuracy  : 0.3966
# Top-5 accuracy  : 0.6252
# Balanced acc    : 0.3966
# Macro precision : 0.4055
# Macro recall    : 0.3966
# Macro F1        : 0.3911

# %% [markdown]
# Confusion Matrix and Worst Species Pairs

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(df['true'], df['pred'], labels=range(num_classes))

plt.figure(figsize=(7, 6))
plt.imshow(cm, cmap='viridis', vmax=np.percentile(cm, 99.9))
plt.colorbar(label='count')
plt.xlabel('Predicted'); plt.ylabel('True')
plt.title(f'Confusion matrix ({num_classes} classes) — {RUN_ID}')
plt.tight_layout()
plt.savefig(os.path.join(CKPT, f'{RUN_ID}_confusion.png'), dpi=150)
plt.show()

off = cm.copy()
np.fill_diagonal(off, 0)
rows, cols = np.unravel_index(np.argsort(off, axis=None)[::-1][:15], off.shape)

print("\ncount  true species  →  predicted as")
for a, b in zip(rows, cols):
    print(f"{off[a,b]:5d}  {class_names[a]}  →  {class_names[b]}")
# Out:
# count  true species  →  predicted as
#     6  04275_Animalia_Chordata_Aves_Passeriformes_Turdidae_Sialia_sialis  →  04274_Animalia_Chordata_Aves_Passeriformes_Turdidae_Sialia_mexicana
#     5  07066_Plantae_Tracheophyta_Magnoliopsida_Asterales_Asteraceae_Vernonia_gigantea  →  07067_Plantae_Tracheophyta_Magnoliopsida_Asterales_Asteraceae_Vernonia_missurica
#     4  07067_Plantae_Tracheophyta_Magnoliopsida_Asterales_Asteraceae_Vernonia_missurica  →  07066_Plantae_Tracheophyta_Magnoliopsida_Asterales_Asteraceae_Vernonia_gigantea
#     3  05330_Animalia_Mollusca_Gastropoda_Stylommatophora_Achatinidae_Rumina_decollata  →  02761_Animalia_Chordata_Actinopterygii_Cypriniformes_Catostomidae_Catostomus_commersonii
#     3  07597_Plantae_Tracheophyta_Magnoliopsida_Cornales_Cornaceae_Cornus_drummondii  →  09508_Plantae_Tracheophyta_Magnoliopsida_Rosales_Urticaceae_Boehmeria_cylindrica
#     3  04808_Animalia_Chordata_Mammalia_Rodentia_Echimyidae_Myocastor_coypus  →  03663_Animalia_Chordata_Aves_Gruiformes_Rallidae_Gallirallus_australis
#     3  08600_Plantae_Tracheophyta_Magnoliopsida_Lamiales_Orobanchaceae_Odontites_vulgaris  →  09180_Plantae_Tracheophyta_Magnoliopsida_Ranunculales_Papaveraceae_Fumaria_officinalis
#     3  06968_Plantae_Tracheophyta_Magnoliopsida_Asterales_Asteraceae_Scorzoneroides_autumnalis  →  05853_Plantae_Tracheophyta_Liliopsida_Asparagales_Amaryllidaceae_Habranthus_tubispathus
#     3  03748_Animalia_Chordata_Aves_Passeriformes_Corvidae_Corvus_albus  →  03171_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Milvus_migrans
#     3  03439_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_maximus  →  03427_Animalia_Chordata_Aves_Charadriiformes_Laridae_Leucophaeus_pipixcan
#     3  03240_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_buccinator  →  03244_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_olor
#     3  02855_Animalia_Chordata_Actinopterygii_Perciformes_Mullidae_Parupeneus_spilurus  →  02885_Animalia_Chordata_Actinopterygii_Perciformes_Serranidae_Serranus_scriba
#     3  01196_Animalia_Arthropoda_Insecta_Lepidoptera_Geometridae_Dysstroma_citrata  →  01290_Animalia_Arthropoda_Insecta_Lepidoptera_Geometridae_Phrissogonus_laticostata
#     2  06732_Plantae_Tracheophyta_Magnoliopsida_Asterales_Asteraceae_Crassocephalum_crepidioides  →  09516_Plantae_Tracheophyta_Magnoliopsida_Rosales_Urticaceae_Urtica_dioica
#     2  05073_Animalia_Chordata_Reptilia_Squamata_Scincidae_Lampropholis_delicata  →  02911_Animalia_Chordata_Actinopterygii_Siluriformes_Ictaluridae_Ameiurus_natalis

# %% [markdown]
# Per-Class F1 and Failure Examples

# %%
_, _, f1_per, _ = precision_recall_fscore_support(
    df['true'], df['pred'], average=None, labels=range(num_classes), zero_division=0)

plt.figure(figsize=(9, 3.5))
plt.bar(range(num_classes), np.sort(f1_per)[::-1], width=1.0)
plt.xlabel('Species (sorted by F1)'); plt.ylabel('F1 score')
plt.title(f'Per-class F1 — {RUN_ID}')
plt.tight_layout()
plt.savefig(os.path.join(CKPT, f'{RUN_ID}_perclass_f1.png'), dpi=150)
plt.show()

print(f"Species never correctly identified: {(f1_per == 0).sum()} / {num_classes}")

print("\nMost confident mistakes:")
for _, row in df[df.pred != df.true].nlargest(10, 'confidence').iterrows():
    print(f"{row.confidence:.2f}  {class_names[row.true]}  called  {class_names[row.pred]}")
    print(f"      {row.filepath}")
# Out:
# Species never correctly identified: 23 / 500
#
# Most confident mistakes:
# 0.99  05230_Animalia_Mollusca_Bivalvia_Mytilida_Mytilidae_Mytilus_edulis  called  07650_Plantae_Tracheophyta_Magnoliopsida_Dipsacales_Caprifoliaceae_Lonicera_morrowii
#       C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\COMP9517_Team_500_40_10\content/Team_Dataset\test\05230_Animalia_Mollusca_Bivalvia_Mytilida_Mytilidae_Mytilus_edulis\e896510b-5924-467e-8189-f780f4b1a695.jpg
# 0.99  00266_Animalia_Arthropoda_Insecta_Coleoptera_Chrysomelidae_Anomoea_laticlavia  called  07650_Plantae_Tracheophyta_Magnoliopsida_Dipsacales_Caprifoliaceae_Lonicera_morrowii
#       C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\COMP9517_Team_500_40_10\content/Team_Dataset\test\00266_Animalia_Arthropoda_Insecta_Coleoptera_Chrysomelidae_Anomoea_laticlavia\451ce551-a38a-4eb4-bb22-1d97369b8ebe.jpg
# 0.96  00718_Animalia_Arthropoda_Insecta_Hymenoptera_Cimbicidae_Cimbex_americanus  called  05311_Animalia_Mollusca_Gastropoda_Nudibranchia_Dorididae_Doris_montereyensis
#       C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\COMP9517_Team_500_40_10\content/Team_Dataset\test\00718_Animalia_Arthropoda_Insecta_Hymenoptera_Cimbicidae_Cimbex_americanus\95920a51-0649-48e9-b0c5-9a39b3c859f1.jpg
# 0.95  07358_Plantae_Tracheophyta_Magnoliopsida_Caryophyllales_Cactaceae_Echinocactus_platyacanthus  called  05311_Animalia_Mollusca_Gastropoda_Nudibranchia_Dorididae_Doris_montereyensis
#       C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\COMP9517_Team_500_40_10\content/Team_Dataset\test\07358_Plantae_Tracheophyta_Magnoliopsida_Caryophyllales_Cactaceae_Echinocactus_platyacanthus\ab3f6cc1-b7db-422d-8c4b-fda9c54cda2d.jpg
# 0.95  06588_Plantae_Tracheophyta_Magnoliopsida_Asterales_Alseuosmiaceae_Alseuosmia_macrophylla  called  09253_Plantae_Tracheophyta_Magnoliopsida_Ranunculales_Ranunculaceae_Hydrastis_canadensis
#       C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\COMP9517_Team_500_40_10\content/Team_Dataset\test\06588_Plantae_Tracheophyta_Magnoliopsida_Asterales_Alseuosmiaceae_Alseuosmia_macrophylla\ce09cad9-6032-4669-90f0-98edb5ca3060.jpg
# 0.94  01405_Animalia_Arthropoda_Insecta_Lepidoptera_Hesperiidae_Thymelicus_lineola  called  01353_Animalia_Arthropoda_Insecta_Lepidoptera_Hesperiidae_Copaeodes_minima
#       C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\COMP9517_Team_500_40_10\content/Team_Dataset\test\01405_Animalia_Arthropoda_Insecta_Lepidoptera_Hesperiidae_Thymelicus_lineola\8121320b-4e25-4ac2-970a-ad46b145cb88.jpg
# 0.94  02534_Animalia_Arthropoda_Insecta_Odonata_Libellulidae_Orthetrum_cancellatum  called  02532_Animalia_Arthropoda_Insecta_Odonata_Libellulidae_Orthetrum_brunneum
#       C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\COMP9517_Team_500_40_10\content/Team_Dataset\test\02534_Animalia_Arthropoda_Insecta_Odonata_Libellulidae_Orthetrum_cancellatum\7589d76d-4539-4264-ad54-4d563aa33270.jpg
# 0.94  01295_Animalia_Arthropoda_Insecta_Lepidoptera_Geometridae_Pleuroprucha_insulsaria  called  01241_Animalia_Arthropoda_Insecta_Lepidoptera_Geometridae_Idiodes_apicata
#       C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\COMP9517_Team_500_40_10\content/Team_Dataset\test\01295_Animalia_Arthropoda_Insecta_Lepidoptera_Geometridae_Pleuroprucha_insulsaria\7eee1be2-a143-4867-b284-d9be25e92965.jpg
# 0.93  04057_Animalia_Chordata_Aves_Passeriformes_Parulidae_Mniotilta_varia  called  03297_Animalia_Chordata_Aves_Caprimulgiformes_Podargidae_Podargus_strigoides
#       C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\COMP9517_Team_500_40_10\content/Team_Dataset\test\04057_Animalia_Chordata_Aves_Passeriformes_Parulidae_Mniotilta_varia\fe72c3f8-2fc7-4b99-8958-4b1af83e7439.jpg
# 0.93  01789_Animalia_Arthropoda_Insecta_Lepidoptera_Nymphalidae_Asterocampa_celtis  called  01790_Animalia_Arthropoda_Insecta_Lepidoptera_Nymphalidae_Asterocampa_clyton
#       C:\Users\alexs\Desktop\UNSW\2026T2\COMP9517\COMP9517_Team_500_40_10\content/Team_Dataset\test\01789_Animalia_Arthropoda_Insecta_Lepidoptera_Nymphalidae_Asterocampa_celtis\ea318374-bebc-4a8f-82db-1e33ef0d76ad.jpg
