# %% [markdown]
# <a href="https://colab.research.google.com/github/Gr3a/COMP9517-Group-102/blob/main/Download_Script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/COMP9517 Group Project
# Out:
# /content/drive/MyDrive/COMP9517 Group Project

# %%
# Training Images (42GB)
# !wget https://ml-inat-competition-datasets.s3.amazonaws.com/2021/train_mini.tar.gz

# Training Annotations (42MB)
# !wget https://ml-inat-competition-datasets.s3.amazonaws.com/2021/train_mini.json.tar.gz

# Validation Images (8.4GB)
# !wget https://ml-inat-competition-datasets.s3.amazonaws.com/2021/val.tar.gz

# Validation Annotations (9.4MB)
# !wget https://ml-inat-competition-datasets.s3.amazonaws.com/2021/val.json.tar.gz
# Out:
# --2026-07-19 11:12:15--  https://ml-inat-competition-datasets.s3.amazonaws.com/2021/train_mini.tar.gz
# Resolving ml-inat-competition-datasets.s3.amazonaws.com (ml-inat-competition-datasets.s3.amazonaws.com)... 3.5.93.103, 16.12.64.58, 3.5.88.97, ...
# Connecting to ml-inat-competition-datasets.s3.amazonaws.com (ml-inat-competition-datasets.s3.amazonaws.com)|3.5.93.103|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44636137542 (42G) [application/gzip]
# Saving to: ‘train_mini.tar.gz’
#
# train_mini.tar.gz   100%[===================>]  41.57G  40.3MB/s    in 17m 46s
#
# 2026-07-19 11:30:02 (39.9 MB/s) - ‘train_mini.tar.gz’ saved [44636137542/44636137542]
#
# --2026-07-19 11:30:03--  https://ml-inat-competition-datasets.s3.amazonaws.com/2021/train_mini.json.tar.gz
# Resolving ml-inat-competition-datasets.s3.amazonaws.com (ml-inat-competition-datasets.s3.amazonaws.com)... 52.219.177.218, 3.5.132.66, 3.5.132.200, ...
# ...
